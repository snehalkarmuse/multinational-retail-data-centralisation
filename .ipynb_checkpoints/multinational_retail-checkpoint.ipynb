# %%
import pandas as pd
import psycopg2
from yaml import safe_load
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:password@localhost:5432/postgres')
class DatabaseConnector:
    
    def read_db_creds(self):
        with open('my_yaml.yaml', 'r') as f:
            #df = pd.json_normalize(safe_load(f))
            df = safe_load(f)
        return df
    
    def init_db_engine(self):
        df = self.read_db_creds()
        self.db_engine = psycopg2.connect(host = df["RDS_HOST"],user = df["RDS_USER"],password = df["RDS_PASSWORD"],database = df["RDS_DATABASE"],port = df["RDS_PORT"])
        return self.db_engine
    
    def list_db_tables(self):
        self.db_engine = self.init_db_engine()
        self.cur = self.db_engine.cursor()
        self.cur.execute("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public' ")
        list_of_tables = self.cur.fetchall()
        
        #print(list_of_tables)
        return list_of_tables
    
    def upload_to_db(self,df,table_name):
        print(table_name)
        df.to_sql(table_name,engine,schema='public',if_exists='append')


dbconnector = DatabaseConnector()
dbconnector.list_db_tables()
#dbconnector.upload_to_db(dataframe,"legancy_user")
# Out:
# [('legacy_store_details',),
#  ('legacy_users',),
#  ('orders_table',),
#  ('dim_user',)]

# %%
import pandas as pd
import psycopg2
from yaml import safe_load
import db_connect as dbc

class DataExtractor:
    def read_rds_table(self, db_connector,table_name):
        list_of_tables = db_connector.list_db_tables()
        print(list_of_tables)
        df = pd.read_sql_query("select * from legacy_users", db_connector.init_db_engine())
        df = pd.DataFrame(df)
        
        #print(df)
        return df


dbconnector = dbc.DatabaseConnector()
db_extractor = DataExtractor()
db_extractor.read_rds_table(dbconnector,"legacy_user")
# Out:
# [('legacy_store_details',), ('legacy_users',), ('orders_table',), ('dim_user',)]
# /var/folders/l9/fpycfm1d5z18rqn65p1nd4qw0000gn/T/ipykernel_18045/2614943517.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("select * from legacy_users", db_connector.init_db_engine())
#        index first_name last_name date_of_birth                       company  \
# 0          0   Sigfried     Noack    1990-09-30            Heydrich Junitz KG
# 1          1        Guy     Allen    1940-12-01                       Fox Ltd
# 2          2      Harry  Lawrence    1995-08-02     Johnson, Jones and Harris
# 3          3     Darren   Hussain    1972-09-23                   Wheeler LLC
# 4          4      Garry     Stone    1952-12-20                    Warner Inc
# ...

# %%
import pandas as pd
import psycopg2
import db_connect as dbc
import data_extraction as dbe

class DataCleaning:
    def clean_user_data(self):
        
        self.df = db_extractor.read_rds_table(db_connector,"legacy_user")
        
        # check any null value
        print("Any Null values:", self.df.isnull().values.any())
        # drop null 
        self.df.dropna()
        # null count in whole table
        na_count = self.df.isna().sum().sum()
        print("Null Values:", na_count)
        # any duplicates in table. count rows
        self.df = self.df.drop_duplicates()
        duplicate_row_count = self.df.shape[0]
        print("duplicate row ", duplicate_row_count)       

        self.df.drop(self.df.loc[self.df['first_name'].str.contains(r'[0-9]') == True].index,axis = 0,inplace = True)
        self.df.drop(self.df.loc[self.df['last_name'].str.contains(r'[0-9]') == True].index,axis = 0,inplace = True)
        self.df.drop(self.df.loc[self.df['date_of_birth'].str.contains('NULL',case = False)].index, axis = 0,inplace=True)
        self.df.drop(self.df.loc[self.df['date_of_birth'].str.contains('%a%',case = False)].index,axis = 0,inplace = True)
        self.df.drop(self.df.loc[self.df['date_of_birth'].str.contains('-') == False].index,axis = 0,inplace = True)

        self.df.drop(self.df.loc[self.df['join_date'].str.contains('-') == False].index,axis = 0,inplace = True)
        self.df.drop(self.df.loc[self.df['email_address'].str.contains('@') == False].index,axis = 0,inplace = True)
        
        self.df.drop(self.df.loc[self.df['country'].str.contains(r'[0-9]') == True].index,axis = 0,inplace = True)
        self.df.drop(self.df.loc[self.df['country_code'].str.len() != 2].index,axis = 0,inplace = True)
       
        self.df.drop(self.df.loc[self.df['phone_number'].str.contains(r'[a-z]') == True].index,axis = 0,inplace = True)
        
        self.df['date_of_birth'] = self.df['date_of_birth'].astype('datetime64[ns]')
        self.df['date_of_birth'] = pd.to_datetime(self.df["date_of_birth"]).dt.normalize()
        
        self.df['join_date'] = self.df['join_date'].astype('datetime64[ns]')
        self.df['join_date'] = pd.to_datetime(self.df["join_date"]).dt.normalize()

db_connector = dbc.DatabaseConnector()
db_extractor = dbe.DataExtractor()
data_cleaning = DataCleaning()
data_cleaning.clean_user_data()
db_connector.upload_to_db(data_cleaning.df,'dim_user')
# Out:
# [('legacy_store_details',), ('legacy_users',), ('orders_table',), ('dim_user',)]
# Any Null values: False
# Null Values: 0
# duplicate row  15320
# /Users/nitin.karmuse/aicore/multinational-retail-data-centralisation/data_extraction.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("select * from legacy_users", db_connector.init_db_engine())
# dim_user

# %%
print(df)
# Out:
# None
