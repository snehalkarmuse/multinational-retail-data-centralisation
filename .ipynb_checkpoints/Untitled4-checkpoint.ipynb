# %%
import pandas as pd
import psycopg2
import db_connect as dbc
import data_extraction as dbe
import datetime as dt
from sqlalchemy import text
import numpy as np
class DataCleaning:
    def convert_product_weights(self,s3_data):
        s3_data.dropna(inplace = True)
        s3_data.drop(s3_data.loc[s3_data['weight'].str.extract(r'(\d*\.?\d+)(kg|g|l|ml)') == False].index,axis = 0,inplace = True)
        print(type(s3_data))
        print(s3_data.shape[0])
        #len(list(final_df.iterrows())
        for row in range(5):
            s3_data['weight'].apply(lambda x: self.weight_conversion(x))
        print(s3_data.head(5))
        #s3_data['date_added']= pd.to_datetime(s3_data['date_added'], infer_datetime_format=True,errors = 'coerce')
            
    def weight_conversion(self,weight_str):
        
        weight_rgx = re.compile(r'(\d*\.?\d+)(kg|g|l|ml)')
        mo = weight_rgx.search(weight_str)
        wn = float(mo.group(1)) 
        if mo.group(2)=='g' or mo.group(2)=='ml':
            wn = wn/1000
        return wn
        

db_connector = dbc.DatabaseConnector()
db_connector.init_db_engine()
db_extractor = dbe.DataExtractor()
db_cleaning = DataCleaning()
s3_data = db_extractor.extract_from_s3("s3://data-handling-public/products.csv")
db_cleaning.convert_product_weights(s3_data)
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost:5432/postgres)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[131], line 35
#      33 db_cleaning = DataCleaning()
#      34 s3_data = db_extractor.extract_from_s3("s3://data-handling-public/products.csv")
# ---> 35 db_cleaning.convert_product_weights(s3_data)
#
# Cell In[131], line 11, in DataCleaning.convert_product_weights(self, s3_data)
#       9 def convert_product_weights(self,s3_data):
#      10     s3_data.dropna(inplace = True)
# ---> 11     s3_data.drop(s3_data.loc[s3_data['weight'].str.extract(r'(\d*\.?\d+)(kg|g|l|ml)') != True].index,axis = 0,inplace = True)
#      12     print(type(s3_data))
#      13     print(s3_data.shape[0])
#
# File ~/miniconda3/envs/multi_retail_data_env/lib/python3.10/site-packages/pandas/core/indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
# ...

# %%
import pandas as pd
import psycopg2
from yaml import safe_load
import db_connect as dbc
from sqlalchemy import text
import tabula
import requests
import boto3

class DataExtractor:
    dict_to_df = pd.DataFrame()
    
    def extract_from_s3(self,link):
        s3_data = pd.read_csv(link)
        return s3_data


s3 = boto3.client("s3")
#s3.download_file("s3://data-handling-public/products.csv")
#print(s3)
data_retrieve_link = "https://aqj7u5id95.execute-api.eu-west-1.amazonaws.com/prod/store_details/"
store_api_config = {"x-api-key":"yFBQbwXe9J3sd6zWVAMrK6lcxxr0q1lr2PT6DDMX"}
pdf_path = "https://data-handling-public.s3.eu-west-1.amazonaws.com/card_details.pdf"
dbconnector = dbc.DatabaseConnector()
db_extractor = DataExtractor()
#db_extractor.read_rds_table(dbconnector,"legacy_users")
#db_extractor.retrieve_pdf_data(pdf_path)
#no_of_stores = db_extractor.list_number_of_stores('https://aqj7u5id95.execute-api.eu-west-1.amazonaws.com/prod/number_stores',store_api_config)
#data = db_extractor.add_data_to_dataframe(data_retrieve_link, no_of_stores, store_api_config)
db_extractor.extract_from_s3("s3://data-handling-public/products.csv")
# Out:
#       Unnamed: 0                                 product_name product_price  \
# 0              0  FurReal Dazzlin' Dimples My Playful Dolphin        £39.99
# 1              1          Tiffany's World Day Out At The Park        £12.99
# 2              2          Tiffany's World Pups Picnic Playset         £7.00
# 3              3     Tiffany's World Wildlife Park Adventures        £12.99
# 4              4                      Cosatto Cosy Dolls Pram        £30.00
# ...          ...                                          ...           ...
# 1848        1848    Goodmans Qi Autosense In Car Phone Holder        £15.00
# 1849        1849    Goodmans Qi Wireless Charging Phone Stand        £15.00
# 1850        1850                     RAC 12V Wet & Dry Vacuum        £18.00
# 1851        1851    Goodmans Qi Autosense In Car Phone Holder        £15.00
# 1852        1852               Beldray Telescopic Ladder 2.9m        £69.00
#
# ...

# %%
s3_data['weight'] = s3_data['weight'].str.rsplit(r"kg")
print(s3_data['weight'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 s3_data['weight'] = s3_data['weight'].str.rsplit(r"kg")
#       2 print(s3_data['weight'])
#
# File ~/miniconda3/envs/multi_retail_data_env/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~/miniconda3/envs/multi_retail_data_env/lib/python3.10/site-packages/pandas/core/accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
# ...

# %%
import re

weight_rgx = re.compile(r'(\d*\.?\d+)(kg|g|l|ml)')
mo = weight_rgx.search('11630l')
wn = float(mo.group(1))
print('weight number ' , wn)
# Out:
# weight number  11630.0
